# %%
import numpy as np
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import re

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Revanasidda\ Sentiment Analysis of Amazon Reviews

# %%
import os

# ✅ Change to your local project directory
os.chdir(r'C:\Users\Revanasidda\ Sentiment Analysis of Amazon Reviews')

# ✅ Initialize git (only once)
# !git init

# ✅ Stage all changes
# !git add .

# ✅ Commit with a message
# !git commit -m "Initial commit"

# ✅ Set the remote URL (only once)
# !git remote add origin https://github.com/RevanasiddaNK/Sentiment-Analysis-of-Amazon-Reviews.git

# ✅ Push to GitHub
# !git push -u origin main
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 import os
#       3 # ✅ Change to your local project directory
# ----> 4 os.chdir(r'Sentiment Analysis of Amazon Reviews')
#       6 # ✅ Initialize git (only once)
#       7 get_ipython().system('git init')
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'Sentiment Analysis of Amazon Reviews'
